# %% [markdown]
# 1) Implemente um programa que exiba a tabuada do 2 ao 9.

# %%
# %reset -f

for num in range(2,10,1):
  print('A tabuada do',num)
  for i in range(1,11,1):
    print(num,'x',i,'=',num * i)

# %% [markdown]
# 2) Faça um programa para tabular a função: f(x, y) = (x4 +3xy+y3 )/(2xy+3x+4y+2) para x = 2, 4, 6, 8 e y = 1, 3, 5, 7, 9, para cada valor de x. Devem ser impressos os valores de x, de y e de f(x,y).

# %%
# %reset -f

for x in range(2,9,2):
  for y in range(1,10,2):
    f = (x**4 + 3*x*y + y**3) / (2*x*y + 3*x + 4*y + 2)
  print('f (',x,',',y,')', '=', f, sep='')
# Out:
# f (2,9)=9.9875
# f (4,9)=8.959016393442623
# f (6,9)=13.335365853658537
# f (8,9)=24.47087378640777

# %% [markdown]
# Para as questões 3 a 7, rode o programa a seguir:
#
# ch = input("Caractere: ")
# for linha in range(8):
#     for coluna in range(8):
#         if (linha + coluna) % 2 == 0:
#             print(ch, ch, sep = '', end = '')
#         else:
#             print('  ', sep = '', end = '')
#     print()

# %% [markdown]
# 3)  Um programa que desenhe um quadrado totalmente preenchido, como a seguir:

# %%
# %reset -f

ch = input("Caractere: ")
for linha in range(8):
    for coluna in range(8):
       print(ch, ch, sep = '', end = '')
    print()
# Out:
# Caractere: *
# ****************
# ****************
# ****************
# ****************
# ****************
# ****************
# ****************
# ****************

# %%
# %reset -f

simb = input('Digite o caractere que desejar.  ')
tam = int (input('Digite o tamanho. '))

for i in range(tam):
  for j in range(tam):
    print(simb, end='')
  print()
# Out:
# Digite o caractere que desejar.  *
# Digite o tamanho. 5
# *****
# *****
# *****
# *****
# *****

# %% [markdown]
# 4) Um programa que desenhe a diagonal principal do quadrado, como a seguir:

# %%
# %reset -f

ch = input("Caractere: ")
for linha in range(8):
    for coluna in range(8):
        if linha == coluna:
            print(ch, ch, sep = '', end = '')
        else:
            print('  ', sep = '', end = '')
    print()
# Out:
# Caractere: *
# **
#   **
#     **
#       **
#         **
#           **
#             **
#               **

# %% [markdown]
# 5) Um programa que desenhe a diagonal principal e a diagonal secundária do quadrado, como a seguir:

# %%
# %reset -f

ch = input("Caractere: ")
tam = int (input('Insira o tamanho : '))
for linha in range(tam):
    for coluna in range(tam):
      if linha == coluna or linha + coluna == tam - 1:
        print(ch, ch, sep = '', end = '')
      else:
        print('  ', sep = '', end = '')
    print()    
 

#  00 01 02 03 04 05
#  10 11 12 13 14 15
#  20 21 22 23 24 25
#  30 31 32 33 34 35
#  40 41 42 43 44 45
#  50 51 52 53 54 55
# Out:
# Caractere: *
# Insira o tamanho : 5
# **      **
#   **  **
#     **
#   **  **
# **      **

# %% [markdown]
#  6) Um programa que desenhe um triângulo retângulo com a base voltada para baixo, como a seguir:

# %%
# %reset -f


tam = int (input('Insira o tamanho do triângulo.  '))

for i in range(tam):
  for j in range(i):
    print('*',end=' ',sep=' ')
  print()

#  00 01 02 03 04 05
#  10 11 12 13 14 15
#  20 21 22 23 24 25
#  30 31 32 33 34 35
#  40 41 42 43 44 45
#  50 51 52 53 54 55
# Out:
# Insira o tamanho do triângulo.  6
#
# *
# * *
# * * *
# * * * *
# * * * * *

# %% [markdown]
# 7) Um programa que desenhe um triângulo retângulo com a base voltada para cima, como a seguir:

# %%
# %reset -f

tam = int (input('Insira o tamanho da pirâmide  '))
caractere = input('Insira qual caractere deseja que esteja no triângulo  ')

for i in range(tam,0,-1):
  for j in range(i):
    print(caractere,end=' ',sep=' ')
  print()

#  00 01 02 03 04 05
#  10 11 12 13 14 15
#  20 21 22 23 24 25
#  30 31 32 33 34 35
#  40 41 42 43 44 45
#  50 51 52 53 54 55

# %% [markdown]
# 8) Crie um algoritmo que simule o funcionamento de um caixa de supermercado. O caixa fica aberto até o fim do expediente e pode processar a compra de vários clientes.
# Cada cliente pode comprar vários itens. Ao ler cada item deve ser exibida uma mensagem para o operador do caixa perguntando se há mais itens a serem processados. Ao final, exiba quanto a compra custou ao cliente. E então solicite do operador do caixa a informação se deseja fechar o caixa.
# Quando o caixa for fechado, exiba quanto de dinheiro aquele caixa apurou no dia.

# %%
# %reset -f

apurado = 0
fecharCaixa = 'n'
while fecharCaixa == 'n':
  temItem = (input('Tem itens ?'))
  valorCompra = 0
  while temItem == 's':
    nomeItem = input('Nome : ')
    valorItem = int (input('Valor : R$ '))
    quantItem = int (input('Quantidade : '))
    valorCompra = valorCompra + valorItem * quantItem
    temItem = input('Tem mais itens para registrar ? ')
    print('O valor da compra é igual a : R$ ',valorCompra)
  apurado = apurado + valorCompra
  fecharCaixa = input('Deseja fechar o caixa ? ')
print('O apurado do dia é igual a : R$ ',apurado)
