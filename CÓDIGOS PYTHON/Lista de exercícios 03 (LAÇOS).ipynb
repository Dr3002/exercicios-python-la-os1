# %% [markdown]
# 1) Faça um programa que peça uma nota, entre zero e dez. Mostre uma mensagem caso o valor seja inválido e continue pedindo até que o usuário informe um valor válido.

# %%
# %reset -f

num = int (input('Digite uma número.'))

while num < 0 or num > 10:
  print('Valor inválido.')
  num = int (input('Digite uma número entre 0 e 10.'))
# Out:
# Digite uma número.12
# Valor inválido.
# Digite uma número.12
# Valor inválido.
# Digite uma número.7

# %% [markdown]
# 2) Faça um programa que leia um nome de usuário e a sua senha e não aceite a senha igual ao nome do usuário, mostrando uma mensagem de erro e voltando a pedir as informações.

# %%
# %reset -f

usuario = input('Digite seu usuário.')
senha = input('senha :')

while usuario == senha:
  print('Erro404')
  input('Digite sua senha novamente')

# %% [markdown]
# 3) Supondo que a população de um país A seja da ordem de 80000 habitantes com uma taxa anual de crescimento de 3% e que a população de B seja 200000 habitantes com uma taxa de crescimento de 1.5%. Faça um programa que calcule e escreva o número de anos necessários para que a população do país A ultrapasse ou iguale a população do país B, mantidas as taxas de crescimento.

# %%
# %reset -f

popA = int (input('Insira o número de habitantes da cidade A. '))
popB = int (input('Insira o número de habitantes da cidade B '))
anos = 0

while popA < popB:
  popA = popA + popA * 3/100
  popB = popB + popB * 1.5/100
  anos = anos + 1
print('Serão necessários',anos,'anos')

# %% [markdown]
# 4) Faça um programa que imprima na tela os números de 1 a 20, um abaixo do outro. Depois modifique o programa para que ele mostre os números um ao lado do outro.

# %%
# %reset -f

for i in range(1,21,1):
  print(i)

# %%
# %reset -f

for i in range(1,21,1):
  print(i,end='  ')

# %% [markdown]
# 5) Faça um programa que leia 10 números e informe o maior número.

# %%
# %reset -f

maior = int (input('Digite um número. '))

for i in range(9):
  num = int (input('Digite um número. '))
  if num > maior:
     maior = num
print('O maior número é :',maior)

# %% [markdown]
# 6) Faça um programa que leia 10 números e informe a soma e a média dos números.

# %%
# %reset -f

soma = 0

for i in range(10):
  num = int (input('Digite um número. '))
  soma = soma + num
media = soma / 10
print('O valor da soma é:',soma,'e o valor da média é ',media)

# %% [markdown]
# 7) Faça um programa que imprima na tela apenas os números ímpares entre 1 e 50

# %%
# %reset -f

for i in range(1,51,2):
  print(i)

# %% [markdown]
# 8) Faça um programa que receba dois números inteiros e gere os números inteiros que estão no intervalo compreendido por eles.

# %%
# %reset -f

num1 = int (input('Digite um número.'))
num2 = int (input('Digite um número.'))
num1_soma = num1 + 1

print('Os números entre',num1,'e',num2,'são : ',end=' ')
for i in range(num1_soma ,num2):
 print(i,end=' ')
# Out:
# Digite um número.3
# Digite um número.9
# Os números entre 3 e 9 são :  4 5 6 7 8

# %% [markdown]
# 9) Desenvolva um gerador de tabuada, capaz de gerar a tabuada de qualquer número inteiro entre 1 a 10. O usuário deve informar de qual número ele deseja ver a tabuada. A saída deve ser conforme o exemplo abaixo:
#
# Tabuada de 5:
#
# 5 X 1 = 5
#
#
# 5 X 2 = 10
#
#
# ...
#
#
# 5 X 10 = 50

# %%
# %reset -f

num = int (input('Digite o número que deseja ver a tabuada.'))
print('Tabuada de ',num,':')
for i in range(1,11,1):
  num_mult = num * i
  print(num ,'x',i ,'=',num_mult)

# %% [markdown]
# 10) Faça um programa que peça dois números, base e expoente, calcule e mostre o primeiro número elevado ao segundo número. Não utilize a função de potência da linguagem.

# %%
# %reset -f

base = int (input('Digite a base do seu número. '))
exp = int (input('Digite o expoente do seu número. '))
potencia = 1
for i in range(exp):
 potencia = potencia * base
print('O número',base,'elevado a ',exp,'é igual a',potencia)

# %% [markdown]
# 13) Faça um programa que calcule o fatorial de um número inteiro fornecido pelo usuário. Ex.: 5!=5.4.3.2.1=120

# %%
# %reset -f

num = int (input('Digite o número que deseja fatorar. '))
fatorial = 1

for i in range(num,1,-1):
  fatorial = fatorial * i
print('O fatorial de',num,'é',fatorial)
# Out:
# Digite o número que deseja fatorar. 5
# O fatorial de 5 é 120

# %% [markdown]
# 14) Faça um programa que, dado um conjunto de N números, determine o menor valor, o maior valor e a soma dos valores.

# %%
# %reset -f

N1 = int (input('Digite um número.'))
N2 = int (input('Digite um número.'))

if N1 > N2:
   print('O maior é',N1,'e o menor é',N2,'e a soma é',N1 + N2)
elif N2 < N1:
   print('O maior é',N2,'e o menor é',N1,'e a soma é',N1 + N2)

# %% [markdown]
# 15) Faça um programa que peça um número inteiro e determine se ele é ou não um número primo. Um número primo é aquele que é divisível somente por ele mesmo e por 1.

# %%
# %reset -f

num = int (input('Digite um número.'))

primo = True
for i in range(2,num):
  if num % i == 0:
    primo = False

if primo == True:
  print('É primo.')
else:
  print('Não é primo.')
# Out:
# Digite um número.7
# É primo.

# %% [markdown]
# 16) Faça um programa que peça para n pessoas a sua idade, ao final o programa deverá verificar se a média de idade da turma varia entre 0 e 25,26 e 60 e maior que 60; e então, dizer se a turma é jovem, adulta ou idosa, conforme a média calculada.

# %%
# %reset -f

soma = 0

n = int (input('Quantas pessoas deseja inserir a idade ? '))

for i in range(n):
   idade = int (input('Digite a sua idade ? '))
   soma = soma + idade
media = soma / n
if media >= 0 and media <= 25:
  print('A média de idade é jovem!!')
elif media >= 26 and media <= 60:
  print('A média da idade é adulta!!')
else:
  print('A média da idade é idosa!!')

# %% [markdown]
# 17) Faça um programa que calcule o número médio de alunos por turma. Para isto, peça a quantidade de turmas e a quantidade de alunos para cada turma. As turmas não podem ter mais de 40 alunos.

# %%
# %reset -f

alunos = 0
soma = 0
turmas = int (input('Insira a quantidade de turmas. '))
for i in range(turmas):
    alunos = int (input('Insira a quantidade de alunos da turma(No máx. 40 alunos por turma!!!)  '))
    if alunos < 40: 
      soma = soma + alunos 
media = soma // turmas
print('O número médio de alunos por turma é :', media)
# Out:
# Insira a quantidade de turmas. 3
# Insira a quantidade de alunos da turma(No máx. 40 alunos por turma!!!)  24
# Insira a quantidade de alunos da turma(No máx. 40 alunos por turma!!!)  27
# Insira a quantidade de alunos da turma(No máx. 40 alunos por turma!!!)  34
# O número médio de alunos por turma é : 28

# %% [markdown]
# 18) Faça um programa que calcule o valor total investido por um colecionador em sua coleção de CDs e o valor médio gasto em cada um deles. O usuário deverá informar a quantidade de CDs e o valor pago em cada um.

# %%
# %reset -f

cd_total = int (input('Digite a sua quantidade de CDs. '))
soma = 0

for i in range(cd_total):
  valor_pago = float (input('Digite o valor pago neste CD '))
  soma = soma + valor_pago
  print('O valor gasto neste CD foi ', valor_pago)
media = soma / cd_total
print('O valor total gasto com a coleção de CDs foi de ',soma,)

# %% [markdown]
# 19) O Sr. Manoel Joaquim possui uma grande loja de artigos de R$ 1,99, com cerca de 10 caixas. Para agilizar o cálculo de quanto cada cliente deve pagar ele desenvolveu um tabela que contém o número de itens que o cliente comprou e ao lado o valor da conta. Desta forma a atendente do caixa precisa apenas contar quantos itens o cliente está levando e olhar na tabela de preços. Você foi contratado para desenvolver o programa que monta esta tabela de preços, que conterá os preços de 1 até 50 produtos, conforme o exemplo abaixo:
# Lojas Quase Dois - Tabela de preços
#
# 1 - R$ 1.99
#
# 2 - R$ 3.98
#
# ...
#
# 50 - R$ 99.50

# %%
# %reset -f

print('TABELA DE PREÇOS:')

for i in range(1,51,1):
  print('Produto',i,':','R$', i * 1.99)

# %% [markdown]
# 20) O Sr. Manoel Joaquim expandiu seus negócios para além dos negócios de 1,99 e agora possui uma loja de conveniências. Faça um programa que implemente uma caixa registradora rudimentar. O programa deverá receber um número desconhecido de valores referentes aos preços das mercadorias. Um valor zero deve ser informado pelo operador para indicar o final da compra. O programa deve então mostrar o total da compra e perguntar o valor em dinheiro que o cliente forneceu, para então calcular e mostrar o valor do troco. (Após esta operação, o programa deverá voltar ao ponto inicial, para registrar a próxima compra. A saída deve ser conforme o exemplo abaixo:) <- Não precisa fazer essa parte, exige laços aninhados.
#
# ***Lojas Tabajara ***
#
# Produto 1: R$ 2.20
#
# Produto 2: R$ 5.80
#
# Produto 3: R$ 0
#
# Total: R$ 9.00
#
# Dinheiro: R$ 20.00
#
# Troco: R$ 11.00
#
# ...

# %%
# %reset -f

produto = 1
soma = 0

while produto != 0:
  produto = float (input('Insira o valor do produto R$ '))
  soma = soma + produto
dinheiro = float (input('Digite quanto o cliente forneceu em dinheiro R$ '))
troco = dinheiro - soma
print('Total : R$', soma)
print('Dinheiro : R$', dinheiro)
print('Troco : R$', troco)

# %% [markdown]
# 21) Foi feita uma estatística em cinco cidades brasileiras para coletar dados sobre acidentes de trânsito. Foram obtidos os seguintes dados:
#
# Código da cidade;
#
# Número de veículos de passeio (em 2019);
#
# Número de acidentes de trânsito com vítimas (em 2019).
#
# Deseja-se saber:
#
# Qual o maior e menor índice de acidentes de trânsito e a que cidade pertence;
#
# Qual a média de veículos nas cinco cidades juntas;
#
# Qual a média de acidentes de trânsito nas cidades com menos de 2.000 veículos de passeio.

# %%
# %reset -f

#imcompleto

maior_acid = 0
menor_acid = 0
soma = 0
soma_2 = 0
cod_cidade = -1
while cod_cidade != 0 :
  cod_cidade = int (input('Insira o código da cidade : ')
  for i in range(5):
    num_vp = int (input('Digite o número de veículos de passeio em 2019 : '))
    num_acid_vit = int (input('Digite o número de acidentes de trânsito com vítimas em 2019 : '))
    soma = soma + num_vp
    media_cidades_vp = soma / 5
    if maior_acid < num_acid_vit:
      maior_acid = num_acid_vit
      if cod_cidade == 1:
        cidade_maior_acid = 1
      elif  cod_cidade == 2:
        cidade_maior_acid = 2
      elif cod_cidade == 3:
        cidade_maior_acid = 3
      elif cod_cidade == 4:
        cidade_maior_acid = 4
      else:
        cidade_maior_acid = 5
    elif menor_acid > num_acid_vit:
      menor_acid = num_acid_vit
      if cod_cidade == 1:
        cidade_menor_acid = 1
      elif  cod_cidade == 2:
        cidade_menor_acid = 2
      elif cod_cidade == 3:
        cidade_menor_acid = 3
      elif cod_cidade == 4:
        cidade_menor_acid = 4
      else:
        cidade_menor_acid = 5
    elif num_vp < 2000:
      soma_2 = soma_2 + num_acid_vit
      media_cidades_acid = soma_2 / 5
    cod_cidade = int (input('Insira o código da cidade : ')) 
print('O maior indice de acidentes pertence a cidade',cidade_maior_acid,'e ele é de : ',maior_acid)
print('O menor indice de acidentes pertence a cidade',cidade_menor_acid,'e ele é de : ',menor_acid)
print('A média de veículos nas cinco cidades juntas é de ',media_cidades_vp,'veículos. ')
print('A média de trânsito nas cidades com menos de 2.000 veículos de passeio é de ',media_cidades_acid,'acidentes')

# %% [markdown]
# 22) Faça um programa que receba o valor de uma dívida e mostre uma tabela com os seguintes dados: valor da dívida, valor dos juros, quantidade de parcelas e valor da parcela.
#
# Os juros e a quantidade de parcelas seguem a tabela abaixo:
#
#   Quantidade de Parcelas  % de Juros sobre o valor inicial da dívida
#
# 1       0
#
# 3       10
#
# 6       15
#
# 9       20
#
# 12      25
#
# Exemplo de saída do programa:
#
# Valor da Dívida Valor dos Juros Quantidade de Parcelas  Valor da Parcela
#
# R$ 1.000,00     0               1                       R$  1.000,00
#
# R$ 1.100,00     100             3                       R$    366,00
#
# R$ 1.150,00     150             6                       R$    191,67

# %%
# %reset -f

#imcompleta

valor_divida = float (input('Digite o valor da divida '))
valor_juros = 0
print('Valor dívida : R$',valor_divida + valor_juros)
for i in range(0,13,3):
  print('Quantidade de parcelas : ',i,)
  for j in range(0,26,5):
    valor_juros = valor_divida * (j / 100)
    print('Valor do juros : ','(',j,'%)',valor_juros)

# %% [markdown]
# 23) Desenvolver um programa para verificar a nota do aluno em uma prova com 10 questões, o programa deve perguntar ao aluno a resposta de cada questão e ao final comparar com o gabarito da prova e assim calcular o total de acertos e a nota (atribuir 1 ponto por resposta certa). Após cada aluno utilizar o sistema deve ser feita uma pergunta se outro aluno vai utilizar o sistema. Após todos os alunos terem respondido informar:
#
# Maior e Menor Acerto;
#
# Total de Alunos que utilizaram o sistema;
#
# A Média das Notas da Turma.
#
# Gabarito da Prova:
#
# 01 - A
#
# 02 - B
#
# 03 - C
#
# 04 - D
#
# 05 - E
#
# 06 - E
#
# 07 - D
#
# 08 - C
#
# 09 - B
#
# 10 - A
#
# Após concluir isto você poderia incrementar o programa permitindo que o professor digite o gabarito da prova antes dos alunos usarem o programa.

# %%
# %reset -f

#IMCOMPLETA

for i in range(1,11):
  print(i,end='')
  resposta = input(' - ')

# %%
# %reset -f

outro_aluno = 's'
while outro_aluno == 's':
  outro_aluno = input('Deseja iniciar o gabarito ?')
  for i in range(1,11):
    print(i,end='')
    resposta = input(' - ')

# %% [markdown]
# 24) Faça um programa que peça um numero inteiro positivo e em seguida mostre este numero invertido.
# Exemplo:
#  	12376489 => 98467321

# %%
# %reset -f

#IMCOMPLETA

num = int (input('Insira um número inteiro '))

while num > 0:

# %% [markdown]
# 25) Faça um programa que mostre os n termos da Série a seguir:
#  S = 1/1 + 2/3 + 3/5 + 4/7 + 5/9 + ... + n/m.
#
#  Imprima no final a soma da série.

# %%
# %reset -f

termos = int (input('Quantos termos deseja ver na série ? '))

contador = 0
for i in range(termos):
  n = i + 1
  m = (n * 2) - 1
  contador = contador + 1
  print(n,'/',m)
print('A soma da serie é igual a : ',contador)

# %% [markdown]
# 26) Sendo H= 1 + 1/2 + 1/3 + 1/4 + ... + 1/N, Faça um programa que calcule o valor de H com N termos.

# %%
# %reset -f

termos = int (input('Quantos termos deseja ver na série ? '))
m = 1
contador = 0
for i in range(termos):
  n = i + 1
  h = 1 / n
  print(m,'/',n)
print('O valor de H é igual a :',h)

# %% [markdown]
# 27) Faça um programa que gera uma lista dos números primos existentes entre 1 e um número inteiro informado pelo usuário.

# %%
# %reset -f

#INCOMPLETO

num = int (input('Qual o número que ver o intervalo de números primos ? '))

primo = True
for i in range(1,num,2):
  if i % 3 != 0:
    primo = True
    print(i)
